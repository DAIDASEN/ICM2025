# %%
import pandas as pd

# %%
#df = pd.read_csv('clean.csv')

from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#scaled_features = scaler.fit_transform(df[['GDP', 'Population', 'Total','Gold','Silver','Bronze']])

# %%
import pandas as pd
from kmodes.kprototypes import KPrototypes


# 示例数据
data = pd.DataFrame({
    'Country': ['USA', 'China', 'Germany', 'Cuba', 'Russia'],
    'GDP_mean': [5.2, 4.8, 4.5, 2.1, 3.9],
    'Population_mean': [3, 4, 2, 1, 3],
    'Total_Medals': [50, 30, 20, 1, 20],  # 分类型数据
})


# 提取特征列
features = data[['GDP_mean', 'Population_mean', 'Total_Medals']]

# 指定分类型数据列的索引
categorical_indices = [2]  # 'System_Type' 是第4列（索引为3）

# 初始化K-prototypes模型
kproto = KPrototypes(n_clusters=2, init='Huang', verbose=2)

# 运行聚类
clusters = kproto.fit_predict(features, categorical=categorical_indices)

# 将聚类结果添加到数据中
data['Cluster'] = clusters
print(clusters)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 1, ncost: 6.75304097591929
# Run: 1, iteration: 2/100, moves: 0, ncost: 6.75304097591929
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 0, ncost: 3.9530409759192895
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 0, ncost: 3.9530409759192895
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 1, ncost: 3.9530409759192895
# Run: 4, iteration: 2/100, moves: 0, ncost: 3.9530409759192895
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 1, ncost: 6.75304097591929
# Run: 5, iteration: 2/100, moves: 0, ncost: 6.75304097591929
# ...

# %%
import pandas as pd
from kmodes.kprototypes import KPrototypes
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# 示例数据
data = pd.DataFrame({
    'Country': ['USA', 'China', 'Germany', 'Cuba', 'Russia'],
    'GDP_mean': [5.2, 4.8, 4.5, 2.1, 3.9],
    'Population_mean': [3, 4, 2, 1, 3],
    'Total_Medals': [50, 30, 20, 1, 20],  # 分类型数据
})

# 提取数值型特征列
numerical_features = data[['GDP_mean', 'Population_mean']]

# 正则化数值型特征
# 方法1：Min-Max 归一化
scaler = MinMaxScaler()
numerical_features_normalized = scaler.fit_transform(numerical_features)

# 方法2：Z-Score 标准化（可选）
# scaler = StandardScaler()
# numerical_features_normalized = scaler.fit_transform(numerical_features)

# 将正则化后的数值型特征与分类型特征合并
features = pd.DataFrame(numerical_features_normalized, columns=['GDP_mean', 'Population_mean'])
features['Total_Medals'] = data['Total_Medals']

# 指定分类型数据列的索引
categorical_indices = [2]  # 'Total_Medals' 是第3列（索引为2）

# 初始化K-prototypes模型
kproto = KPrototypes(n_clusters=2, init='Huang', verbose=2)

# 运行聚类
clusters = kproto.fit_predict(features.values, categorical=categorical_indices)

# 将聚类结果添加到数据中
data['Cluster'] = clusters
print(clusters)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 0, ncost: 0.9559377042769373
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 0, ncost: 0.6610481216662308
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 1, ncost: 0.9559377042769373
# Run: 3, iteration: 2/100, moves: 0, ncost: 0.9559377042769373
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 1, ncost: 0.9559377042769373
# Run: 4, iteration: 2/100, moves: 0, ncost: 0.9559377042769373
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 0, ncost: 0.9559377042769373
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# ...
