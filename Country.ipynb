# %%
import pandas as pd
import pycountry

# %%
cnt = 0
df = pd.read_csv('2025_Problem_C_Data\summerOly_medal_counts.csv')
out = []
for i in range(df.shape[0]):
    NOC = df.iloc[i]['NOC']
    country = pycountry.countries.get(name=NOC)
    if country:

        df.at[i,'NOC'] = country.alpha_3
    else:
        out.append((i,NOC))
        print(i)
df.to_csv('NEW_MEDAL_TABLE.csv')
# Out:
# 4
# 10
# 13
# 14
# 30
# 37
# 40
# 45
# 55
# 56
# 61
# 66
# 75
# 79
# 85
# 102
# 107
# 117
# 118
# 141
# 144
# 152
# 172
# 180
# 203
# 204
# 210
# 218
# 230
# 231
# 235
# 247
# 251
# 256
# 258
# 262
# 266
# 276
# 278
# 282
# 290
# 297
# 303
# 304
# 310
# 311
# 315
# 317
# 321
# 329
# 333
# 342
# 345
# 347
# 351
# 353
# 360
# 368
# 374
# 381
# 385
# 387
# 389
# 394
# 395
# 401
# 404
# 412
# 419
# 428
# 431
# 433
# 434
# 436
# 442
# 445
# 447
# 456
# 463
# 470
# 471
# 473
# 474
# 482
# 488
# 490
# 492
# 498
# 508
# 510
# 519
# 520
# 522
# 531
# 534
# 535
# 537
# 540
# 551
# 553
# 560
# 561
# 568
# 572
# 573
# 585
# 587
# 592
# 598
# 604
# 605
# 606
# 631
# 633
# 635
# 636
# 639
# 643
# 644
# 646
# 647
# 654
# 658
# 659
# 669
# 681
# 682
# 685
# 700
# 706
# 708
# 709
# 716
# 739
# 741
# 758
# 766
# 773
# 776
# 789
# 792
# 797
# 799
# 809
# 815
# 819
# 837
# 845
# 847
# 861
# 862
# 863
# 879
# 893
# 895
# 896
# 902
# 914
# 918
# 924
# 925
# 937
# 944
# 946
# 957
# 972
# 977
# 985
# 988
# ...

# %%
df = pd.read_csv('NEW_MEDAL_TABLE.csv')
for i in range(df.shape[0]):
    if(len(df.iloc[i]['NOC'])!=3):
        # print(i)
        print(df.iloc[i]['NOC'])
